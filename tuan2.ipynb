# %% [markdown]
# bai 21

# %%
#bai21
for i in range(10):
    print('hello, world')

# %%
#bai20 same as 19

# %% [markdown]
# bai 19 days of the week

# %%
#bai19
#print('monday\ntuesday\nwednesday\nthursday\nfriday\nsaturday\nsunday')

#print('monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday', sep='\n')

print('monday')
print('tuesday')
print('wednesday')
print('thursday')
print('friday')
print('saturday')
print('sunday')
# Out:
# monday
# tuesday
# wednesday
# thursday
# friday
# saturday
# sunday

# %% [markdown]
# bai 18 banner sus

# %%
#bai18 banner
print('###   # #      ###  ###')
print(' #    #    #    #    #  ')
print(' #    #     #   #    #  ')
print(' #    #    #    #    #  ')
print(' #    # #       #    #  ')

# %%
#bai 17 draw triangle

# %%
#bai17 draw triangle
print('  *  ')
print(' *** ')
print('*****')

# %% [markdown]
# bai 16 seasons

# %%
#bai16

#print('spring')
#print('summer')
#print('autumn')
#print('winter')

print('spring\nsummer\nautumn\nwinter')

# %% [markdown]
# bai15 wtf is that Sn=6xnx(n-1)+1

# %%
#bai15 
n=int(input())

print(6*n*(n-1)+1)

# %% [markdown]
# bai14 hoan doi gia tri a va b ma khong can khai bao them bien/ham khac

# %%
#bai14
#a=int(input())
##b=int(input())
#a=a+b
#b=a-b
#a=a-b
#print(a, b)


#or
a=int(input())
b=int(input())
a, b=map(int, (b, a))
print(a, b)

# %% [markdown]
# bai 13 hang don vi cua tich a va b

# %%
#bai13
a.b=map(int, input().split())
c=a*b

# %% [markdown]
# bai12 mieng dan rubic

# %%
#bai12
n=int(input())
print(6*n*n)

# %% [markdown]
# bai 11 doi thoi gian

# %%
#bai11
a1,a2=map(int, input().split())
time = a1*3600+a2*60
print(time)

# %% [markdown]
# bai 10 friend names

# %%
#bai10
p1, p2, p3=input().split()
print(p3, p2, p1)

# %% [markdown]
# bai 9 shopping online

# %%
#bai9
x= float(input("nhap gia usd: "))
x=

# %% [markdown]
# bai 8 celsius transfer

# %%
#bai8
n = float(input("nhap nhiet do celcius: "))
f=(9/5)*n+32
print(f"nhiet do f la: {f.2f}")

# %% [markdown]
# bai 7 operation

# %%
#bai7
A = ((13 ** 2) * 3) + 5 
B = 13**2*3 + 5
print(A, B)

# %% [markdown]
# bai 6 string data type
# ord : chuyen ki tu thanh ma unicode
# chr: chuyen ma unicode thanh ki tu
# ki tu thuong = ki tu in hoa + 32

# %%
#bai6
abc=input()
print(ord(abc))
d= ord(abc)-32
print(chr(d))

# %%
bai 5 luy thua

# %%
#bai5
a,b=map(float, input().split())
print(a**b)

# %% [markdown]
# bai 4
# #  map(int, input().split())  #

# %%
#bai4
a1,b1,c1,a2,b2,a3=map(float, input().split())
print(((a1+b1+c1)+(a2+b2)*2+a3*3)/10)

# %% [markdown]
# bai 3 mod and div
# //: chia lay nguyen
# %: chia lay du
# **: luy thua

# %%
#bai 3
a=int(input())
b=int(input())
#a, b=map(int, input().split())
tong = a+b
hieu=a-b
tich=a*b
thuong=a/b
phan_nguyen=a//b
phan_du=a%b
print(f"{a} +{b} = {tong}")
print(f"{a} -{b} = {hieu}")
print(f"{a} *{b} = {tich}")
print(f"{a} /{b} = {thuong}")
print(f"{a} //{b} = {phan_nguyen}")
print(f"{a} %{b} = {phan_du}")






#print(a+b, a-b, a/b, a*b, a//b, a%b, sep= "\n")

# %% [markdown]
# bai 2
# kiểu dữ liệu:
# int: số nguyên
# float: số thực
# bool: đúng/sai (true or false)
# str: chuỗi (string)

# %%
#ham input (bai2)
# n=int(input())
#s= input()
#m=9.9
#n=int(s)
#print(f"kieu chuoi: {s}, kieu so la : {n}")
#print(type(s))
#print(type(n))
#print(type(m))


name = input()
print(f"hello {name} ")

# %%
#ham print (bai1)
print('hello', 'wo', sep= '/', end=" ")
print('world')
print('xin chao \n helo')
ngay=11
thang=3
nam=2026
print(f'{ngay}/{thang}/{nam}')
