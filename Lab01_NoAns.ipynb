# %% [markdown]
# ### Bai 1: Nhap vao một số nguyên, in ra màn hình giá trị gấp đôi của nó

# %%
a = float(input())
a = a*2
print(a)

# %% [markdown]
# ### Problem 2
# #### Write a function that computes (a - b) * c.

# %%
#a = int(input())
#b = int(input())
#c= int(input())
#print((a-b)*c)


a, b, c= map(int, input().split('/'))
print(f'du lieu ban nhap vao la a = {a}, b = {b}, c = {c}')
re= (a-b)*c
print(re)
# Out:
# du lieu ban nhap vao la a = 1, b = 2, c = 3
# -3

# %% [markdown]
# ### Problem 3
# #### Write a function that returns a + b + a * b.

# %%
a = int(input())
b = int(input())
c = int(input())
print(a+b+a*b)

a, b, c= map

# %% [markdown]
# ### Problem 4
# #### Write a function that returns the count of positive integers k such that 1 <= k < n and k > (n - 1) / 2. (Example: n=9 -> 4).

# %%
n = int(input())
count = 0
for k in range (1,n):
    if k>(n-1)/2:
        count=count+1

      
print(count)

# %% [markdown]
# ### Problem 6
# #### Write a function that computes the area of a triangle with side lengths a, b, c (use Heron's formula). Raise ValueError if the sides cannot form a triangle.

# %%
a = int(input())
b = int(input())
c = int(input())
p = (a+b+c)/2
s = p*(p-a)*(p-b)*(p-c)
area = s**(1/2)
print(area)

# %% [markdown]
# ### Problem 7
# #### Write a function that returns True if a, b, c can be the side lengths of a triangle; otherwise return False.

# %%
a = int(input())
b = int(input())
c = int(input())
if a+b>c:
 print('tam giac')
else:
 print('khong la tam giac')

# %% [markdown]
# ### Problem 8
# #### Write a function that returns the character that is n positions after character x in the alphabet.
# #### Preserve case and wrap around within A..Z or a..z.

# %%
x=str(input())
n=int(input())
vitri=ord(x)+n
if ord('A')<=vitri<=ord('Z'):
    print(chr(vitri))


elif ord('a')<=vitri<=ord('z'):
    print(chr(vitri))

else:
    print('khong phai du lieu chu cai')
# Out:
# c

# %% [markdown]
# ### Problem 9
# #### Write a function that converts an uppercase letter to lowercase. If the input is not a single character, raise ValueError.

# %%
data = input("Nhập một ký tự: ")

# Kiểm tra đồng thời 2 điều kiện: độ dài = 1 VÀ là chữ cái
if len(data) == 1 and data.isalpha():
    a= ord(data)-26
    print(chr(a))
else:
    print("Không hợp lệ! Vui lòng chỉ nhập duy nhất một chữ cái.")
# Out:
# G

# %% [markdown]
# ### Problem 10
# #### Write a function that, given a lowercase letter, returns a string containing that letter repeated 10 times.

# %%
c=input ()
string =""
for i in range (10):
    string+=c
print(string, end='')
# Out:
# aaaaaaaaaa

# %% [markdown]
# ### Problem 12
# #### Write a function that returns a right isosceles triangle of height n using '*'.
# #### Line i (1-indexed) has i '*', joined with newlines.
# #### Example with n = 4
# #### *
# #### **
# #### ***
# #### ****

# %%
n = int(input())
list=[]
for i in range (1,n+1):
    list.append('*'*i)
print( '\n'.join(list))  #'\n' tự động xuống dòng
# Out:
# *
# **
# ***
# ****
# *****
