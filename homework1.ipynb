# %%
ten_chu_ho = input('ten chu ho:')
chi_so_thang_truoc = int(input('chi so thang truoc:'))
chi_so_thang_nay = int(input('chi so thang nay:'))
a=chi_so_thang_nay - chi_so_thang_truoc
tien=0
if a <= 50:
    tien = a * 1984
elif a <= 100:
    tien = (50 * 1984) + ((a - 50) * 2050)
elif a <= 200:
    tien = (50 * 1984) + (50 * 2050) + ((a - 100) * 2380)
elif a <= 300:
    tien = (50 * 1984) + (50 * 2050) + (100 * 2380) + ((a - 200) * 2998)
elif a <= 400:
    tien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + ((a - 300) * 3350)
else:
    tien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (100 * 3350) + ((a - 400) * 3460)
print(f'Ho va ten: {ten_chu_ho}')
print(f'Tien phai tra la: {tien*1.08}')
# Out:
# Ho va ten: Người Dơi
# Tien phai tra la: 107136.0

# %% [markdown]
# bai tap 7

# %%
chuoi=input()
if len(chuoi)>=20:
    print(chuoi[4]) 
    print(chuoi[8])
else:
    print('type more plz')
# Out:
# j
# j

# %% [markdown]
# bai tap 6

# %%
a=float(input())
b=float(input())
c=float(input())
if a+b>c:
    p=(a+b+c)/2
    S=(p*(p-a)*(p-b)*(p-c))**(1/2)
    print(S)
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
# 6.0

# %% [markdown]
# bai tap 5

# %%
abc=str(input())
if abc == 'A':
    print('truong hop dac biet')
else:
    c=abc.lower()
    d=ord(c)-1
    e=chr(d)
    print(e)
# Out:
# b

# %% [markdown]
# bai tap 4

# %%
c=(input())
if c.isalpha():
    print(f'{c} la ki tu alphabet')
else:
    print(f'{c} khong phai la ki tu alphabet')
# Out:
# f la ki tu alphabet

# %% [markdown]
# bai tap 3

# %%
abc=str(input())
if abc.isupper():
    print (abc.lower())
else:
    print (abc.upper())
# Out:
# fb

# %% [markdown]
# bai tap 2

# %%
a=float(input())
b=float(input())
r=a/2
S=a*b-r*r*3.14
print(S)
# Out:
# 2.86

# %% [markdown]
# bai tap 1

# %%
n=int(input())
print(n*2)
# Out:
# 6
