# %% [markdown]
# Bài 1: Cho mot danh sach chua cac list so nguyen, lamf phang thanh mot list
# lst = [[1, 3, 2], [4, 5, 6], [2,3]]
# res = [1, 3, 2, 4, 5, 6, 2, 3]

# %% [markdown]
# Bài 2A: Tính tổng cột k của ma trận nxm số nguyên (n, m vào từ bàn phím)

# %%
#1<=k<=m
n,m=map(int, input().split())
k=int(input())

matrix=[]
for _ in range(n):
    row=[]
    for _ in range(m):
        row.append(int(input().split()))
    matrix.append(row)

res=[]
if 1<=k<=m:
    k=k-1
    # tong cua hang i, vi tri k
    tongcot=0
    for i in range(n)
    tongcot=tongcot+matrix[i][k]
else:
    print('invalid')

#tonghang
# for j in range(m):
#     tonghangk=tonghangk+matrix[k][j]

# %% [markdown]
# Bài 2B: Viết hàm zigzag_numbers(n) trả về một chuỗi biểu diễn ma trận n x n chứa các số từ 1 đến n^2. Các hàng cách nhau bởi ký tự xuống
# dòng. Với chỉ số hàng bắt đầu từ 0: hàng chẵn đi từ trái sang phải, hàng lẻ đi từ phải sang trái. Các số trong cùng một hàng cách nhau bởi
# một dấu cách.
# n = 2
# 1 2
# 4 3
# n= 4
# 1 2 3 4
# 8 7 6 5
# 9 10 11 12
# 16 15 14 13

# %%
n=int(input())
matrix=[]

x=1
for i in range(n):
    row=[]
    for j in range(n):
        row.append(x)
        x=x+1
    if i%2==1:
        row.reverse()
    matrix.append(row)

for i in range(n):
    print(matrix[i])    #xem them: ma tran xoan oc cap n
# Out:
# [1, 2, 3, 4]
# [8, 7, 6, 5]
# [9, 10, 11, 12]
# [16, 15, 14, 13]

# %% [markdown]
# Bài 3: Trả về cột (chỉ số bắt đầu từ 0) có tổng cột lớn nhất trong ma trận n x m.
# Viết hàm column_with_max_sum(mat) trả về chỉ số bắt đầu từ 0 của cột có tổng lớn nhất.
# Nếu có nhiều cột cùng tổng lớn nhất, trả về cột có chỉ số nhỏ nhất. - Dùng vòng lặp để tính tổng từng cột. - Không dùng tuple hoặc dictionary.
# n = 2
# m = 3
# mat = [[1, 3, 5],
#        [6, 2, -9]]

# %%
n,m=map(int, input().split())
mat=[]
for _ in range(n):
    row=list(map(int, input().split()))
    mat.append(row)
def column_with_max_sum(mat):
    n=len(mat)
    m=len(mat[0])
    max_col=-999
    col_val=-999
    for j in range(m):
        s=0
        for i in range(n):
            s=s+matrix[i][j]
        if col_val:
            max_col=j
            col_val=s
    return max_col, col_val


print(column_with_max_sum(mat))
# Out:
# (2, 9)

# %% [markdown]
# Bài 4: Trả về hàng (chỉ số bắt đầu từ 0) có tổng hàng nhỏ nhất trong ma trận n x m.
# Viết hàm row_with_min_sum(mat) trả về chỉ số bắt đầu từ 0 của hàng có tổng nhỏ nhất.
# Nếu có nhiều hàng cùng tổng nhỏ nhất, trả về hàng có chỉ số lớn nhất. - Dùng vòng lặp để tính tổng từng hàng. -.
# n = 2
# m = 3
# mat = [[1, 3, 5],
#        [6, 2, -9]]

# %%
mat=[
    [1,3,5],
    [6,7,3],
    [9,0,0]
]

def row_min_sum(mat):
    best=999
    idx=[]
    for i in range(len(mat)):
        l=sum(mat[i])
        if l<=best:
            best=l
            idx.append(i)
            
    return f'{best}, {idx[-1]}'
    

print(row_min_sum(mat))
# Out:
# 9, 2

# %% [markdown]
# Bài 5:
# Cho ma trận vuông cấp n. In ra đường chéo chính và đường chéo phụ của ma trận

# %%
n, m = map(int, input().split())
mat = []
for _ in range(n):
    row = []
    for _ in range(m):
        row.append(int(input()))
    mat.append(row)
cheochinh=[]
cheophu=[]
k=len(mat)
for i in range(k):
    cheochinh.append(mat[i][i])
    cheophu.append(mat[i][k-1-i])

print(cheochinh)
print(cheophu)



print(mat)
# Out:
# [1, 5, 9]
# [3, 5, 7]
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# Bài 6: Cho ma trận nxm số nguyên, thêm vào một cột tại vị trí k. , 1<=k<=m, m la so cot

# %%
#dung insert tren list
mat=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
n=len(mat)

for row in mat:
    for i in range(n):
        if i==2:
            row.insert(1,3)

print(mat)
# Out:
# [[1, 3, 2, 3], [4, 3, 5, 6], [7, 3, 8, 9]]

# %% [markdown]
# Bài 7: Cho ma trận số nguyên nxm, xóa đi hàng k (0 <= k < n).

# %%
# list.pop()/ khong in ra dong thu k


mat=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

mat.pop(1)
print(mat)
# Out:
# [[1, 2, 3], [7, 8, 9]]
