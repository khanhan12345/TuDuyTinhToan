# %% [markdown]
# Linear search

# %%
def linear_search(arr, value):
    for i in range(len(arr)):
    if arr[i] == value:
        return i
    return-1

# %% [markdown]
# Binary search

# %%
def binary_search(arr, value):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == value:
            return mid
        elif arr[mid] < value:
            left = mid + 1
        else:
            right = mid- 1
    return-1

# %% [markdown]
# Bubble Sort is the simplest sorting algorithm that works by repeatedly swapping the adjacent element if they are in the wrong order.

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j] #Swap
                swapped = True
        if not swapped:
            break

# %% [markdown]
# Selection Sort works by repeatedly selecting the smallest (or largest) element from the unsorted portion and swapping it with the first unsorted element.

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j # Update min_idx
        arr[i], arr[min_idx] = arr[min_idx], arr[i]  # Swap

# %% [markdown]
# Insertion Sort works by iteratively inserting each element of an unsorted list into its correct position in a sorted portion of the list.

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i] # Current element to be sorted
        j = i- 1
        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j] # Shift element > key to the right
            j-= 1
        arr[j+1] = key # Insert key at the correct position

# %% [markdown]
# Merge Sort works by recursively dividing the input array into two halves, recursively sorting the two halves and finally merging them back together to obtain the sorted array.

# %%
def merge_sort(arr):   #divide and sort
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = arr[ :mid]
    right = arr[mid:]

    sorted_left = merge_sort(left)
    sorted_right = merge_sort(right)

    return merge(sorted_left, sorted_right)


def merge(left, right):   #merge
    res = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            res. append (left[i])
            i += 1
        else:
            res. append (right[j])
            j += 1

    res . extend (left[i: ])
    res. extend(right[j: ])

    return res

# %% [markdown]
# Quick Sort picks an element as a pivot and partitions the array around the pivot by placing the pivot in its correct position in the sorted array.

# %%
def partition(arr, low, high):  #sort 
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quickSort(arr, low, high):  #divide
    if low < high:
        pi = partition(arr, low, high)
        quickSort(arr, low, pi - 1)
        quickSort(arr, pi + 1, high)

# %% [markdown]
# w7a1 tim kiem nhi phan tren danh sach da sap xep, tra ve -1 neu khong tim thay

# %%
arr=list(map(int, input().split()))
target=int(input())
print(arr)
left=0
right=len(arr)-1
def binary_search(arr, left, right, target):

    while left<=right:
        mid=(left+right)//2
        if arr[mid]==target:
            return mid+1
        elif arr[mid]>target:
            right=mid-1
        elif arr[mid]<target:
            left=mid+1
        
    return -1


print(binary_search(arr, left, right, target))

# %% [markdown]
# w7a2 cho mot danh sach arr va mot so nguyen x. dem xem x xuat hien bao nhieu lan trong danh sach

# %%
def count_occurrences(arr, x):
    dem=0
    for ch in arr:
        if x==ch:
            dem=dem+1
    return dem

arr=list(map(int, input().split()))
x=int(input())
print(count_occurrences(arr, x))

# %% [markdown]
# w7a4 viet ham tim phan tu co so lan xuat hien nhieu nhat trong danh sach, neu cung so lan xuat hien, tra ve phan tu xuat hien truoc  #dung dictionary

# %%
arr=list(map(int, input().split()))
def count_123(arr):
    counts={}
    for ch in arr:
        if ch not in counts:
            counts[ch]=1
        else:
            counts[ch]=counts[ch]+1
    #return counts
    max_count=0
    for i in counts.values():
        if i>max_count:
            max_count=i

    for num in arr:
        if counts[num]==max_count:
            print(f'{num} xuat hien nhieu nhat, som nhat, {max_count} lan')
            return

count_123(arr)

# %% [markdown]
# w7a5 cho danh sach cac so nguyen va mot so X, dem tat ca cac cap (a,b) sao cho a+b =X.c

# %%
arr=list(map(int, input().split()))
print(arr)
X=int(input())
listkq=[]


for a in range(0,len(arr)-1):
    for b in range(1,len(arr)):
        for c in arr: #and c.index()!=a and c.index()!=b:
            if arr[a]*arr[b]==X*c:
                listkq.extend([(arr[a],arr[b])])
                
ok=set(listkq)

print(listkq) 
print(len(ok))         
#print(len(listkq))
# Out:
# [2, 3, 2, 3, 1, 4, 5, 6, -1, 3, 2, 3]
# [(2, 5), (2, 5), (2, 5), (3, 5), (3, 5), (3, 5), (3, 5), (2, 5), (2, 5), (2, 5), (3, 5), (3, 5), (3, 5), (3, 5), (1, 5), (4, 5), (5, 3), (5, 3), (5, 3), (5, 3), (5, 2), (5, 2), (5, 2), (5, 3), (5, 3), (5, 3), (5, 3), (5, 1), (5, 4), (5, 5), (5, 6), (5, -1), (5, 3), (5, 3), (5, 3), (5, 3), (5, 2), (5, 2), (5, 2), (5, 3), (5, 3), (5, 3), (5, 3), (6, 5), (-1, 5), (3, 5), (3, 5), (3, 5), (3, 5), (2, 5), (2, 5), (2, 5)]
# 13
