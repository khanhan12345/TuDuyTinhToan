# %% [markdown]
# w7a16 mang dep neu moi phan tu x trong mang xuat hien dung x lan.kiem tra mang co phai la mang dep khong. neu khong hay xoa di y so (y la so nho nhat co the) de mang con lai thanh mang dep

# %%
arr=list(map(int, input().split()))
def check_beauty_arr(arr):
    dic={}
    for ch in arr:
        if ch not in dic:
            dic[ch]=0
        if ch in dic:
            dic[ch]=dic[ch]+1
    print(dic)
    for k,v in dic.items():
        if int(k)==int(v):
            return True
    return False

d
print(check_beauty_arr(arr))
# Out:
# {1: 1, 2: 2, 3: 3}
# True
